# %%
import numpy as np
import matplotlib.pyplot as plt

# Necssary libraries
import pandas as pd
import statsmodels.api as sm
from sklearn.cross_validation import KFold
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Ridge
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier as RF
from sklearn.neighbors import KNeighborsClassifier as KNN
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.utils import shuffle
from sklearn.metrics import roc_curve, auc
import pylab
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from mpl_toolkits.basemap import Basemap
import re
import pylab as plt
import seaborn
from sklearn.linear_model import LinearRegression
import numpy.random as nprnd
import random
pd.set_option('display.max_columns', 500)
# %matplotlib inline
n = 10
num_samples = 100000

# Generate a random sample.
a = np.random.binomial(n, 0.5, size=num_samples)

# Count the occurrences in the sample.
b = np.bincount(a, minlength=n+1)

# p is the array of probabilities.
p = b / float(b.sum())

plt.bar(np.arange(len(b)) - 0.5, p, width=1, facecolor='b',alpha=0.5,label='Mean=0.5')
plt.xlim(-0.5, n + 0.5)
plt.xlabel("Number of heads (k)")
plt.ylabel("P(k)")


n = 10
num_samples = 100000

# Generate a random sample.
a = np.random.binomial(n, 0.7, size=num_samples)

# Count the occurrences in the sample.
b = np.bincount(a, minlength=n+1)

# p is the array of probabilities.
p = b / float(b.sum())

plt.bar(np.arange(len(b)) - 0.7, p, width=1, facecolor='r',alpha=0.5, label='Mean=0.7')
plt.xlim(-0.5, n + 0.5)
plt.xlabel("Number of heads (k)")
plt.ylabel("P(k)")
plt.legend()
plt.show()


n = 10
num_samples = 100000

# Generate a random sample.
a = np.random.binomial(n, (0.5+0.7)/2, size=num_samples)

# Count the occurrences in the sample.
b = np.bincount(a, minlength=n+1)

# p is the array of probabilities.
p = b / float(b.sum())

plt.bar(np.arange(len(b)) - (0.5+0.7)/2, p, width=1, facecolor='g',alpha=0.5,color='g',label='Mean=0.6')
plt.xlim(-0.5, n + 0.5)
plt.xlabel("Number of heads (k)")
plt.ylabel("P(k)")
plt.legend()
plt.show()

# %%
n = 10
num_samples = 10000

# Generate a random sample.
a = np.random.binomial(n, 0.7, size=num_samples)

# Count the occurrences in the sample.
b = np.bincount(a, minlength=n+1)

# p is the array of probabilities.
p = b / float(b.sum())

plt.bar(np.arange(len(b)) - 0.5, p, width=1, facecolor='g',alpha=0.5,color='g')
plt.xlim(-0.5, n + 0.5)
plt.xlabel("Number of heads (k)")
plt.ylabel("P(k)")

plt.show()

# %%
n = 10
num_samples = 10000

# Generate a random sample.
a = np.random.binomial(n, 0.7, size=num_samples)

# Count the occurrences in the sample.
b = np.bincount(a, minlength=n+1)

# p is the array of probabilities.
p = b / float(b.sum())

plt.bar(np.arange(len(b)) - 0.5, p, width=1, facecolor='r',alpha=0.5)
plt.xlim(-0.5, n + 0.5)
plt.xlabel("Number of heads (k)")
plt.ylabel("P(k)")

plt.show()

# %%
n = 10
num_samples = 10000

# Generate a random sample.
a = np.random.binomial(n, (0.5+0.7)/2, size=num_samples)

# Count the occurrences in the sample.
b = np.bincount(a, minlength=n+1)

# p is the array of probabilities.
p = b / float(b.sum())

plt.bar(np.arange(len(b)) - 0.5, p, width=1, facecolor='g',alpha=0.5)
plt.xlim(-0.5, n + 0.5)
plt.xlabel("Number of heads (k)")
plt.ylabel("P(k)")

plt.show()

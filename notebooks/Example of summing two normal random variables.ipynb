# %%
import numpy as np
import matplotlib.pyplot as plt

# Necssary libraries
import pandas as pd
import statsmodels.api as sm
from sklearn.cross_validation import KFold
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Ridge
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier as RF
from sklearn.neighbors import KNeighborsClassifier as KNN
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.utils import shuffle
from sklearn.metrics import roc_curve, auc
import pylab
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
#from mpl_toolkits.basemap import Basemap
import re
import pylab as plt
#import seaborn
from sklearn.linear_model import LinearRegression
import numpy.random as nprnd
import random
pd.set_option('display.max_columns', 500)
# %matplotlib inline
n = 10
num_samples = 100000

# Generate a random sample.
a = np.random.binomial(n, 0.5, size=num_samples)

# Count the occurrences in the sample.
b = np.bincount(a, minlength=n+1)

# p is the array of probabilities.
p = b / float(b.sum())

plt.bar(np.arange(len(b)) - 0.5, p, width=1, facecolor='b',alpha=0.5,label='Mean=0.5')
plt.xlim(-0.5, n + 0.5)
plt.xlabel("Number of heads (k)")
plt.ylabel("P(k)")


n = 10
num_samples = 100000

# Generate a random sample.
a = np.random.binomial(n, 0.7, size=num_samples)

# Count the occurrences in the sample.
b = np.bincount(a, minlength=n+1)

# p is the array of probabilities.
p = b / float(b.sum())

plt.bar(np.arange(len(b)) - 0.7, p, width=1, facecolor='r',alpha=0.5, label='Mean=0.7',edgecolor='black')
plt.xlim(-0.5, n + 0.5)
plt.xlabel("Number of heads (k)")
plt.ylabel("P(k)")
plt.legend()
plt.show()


n = 10
num_samples = 100000

# Generate a random sample.
a = np.random.binomial(n, (0.5+0.7)/2, size=num_samples)

# Count the occurrences in the sample.
b = np.bincount(a, minlength=n+1)

# p is the array of probabilities.
p = b / float(b.sum())

plt.bar(np.arange(len(b)) - (0.5+0.7)/2, p, width=1, facecolor='g',alpha=0.5,color='g',label='Mean=0.6',edgecolor='black')
plt.xlim(-0.5, n + 0.5)
plt.xlabel("Number of heads (k)")
plt.ylabel("P(k)")
plt.legend()
plt.show()

# %%
n = 10
num_samples = 10000

# Generate a random sample.
a = np.random.binomial(n, 0.7, size=num_samples)


# Count the occurrences in the sample.
b = np.bincount(a, minlength=n+1)

# p is the array of probabilities.
p = b / float(b.sum())

plt.bar(np.arange(len(b)) - 0.5, p, width=1, facecolor='g',alpha=0.5,color='g')
plt.xlim(-0.5, n + 0.5)
plt.xlabel("Number of heads (k)")
plt.ylabel("P(k)")

plt.show()

# %%
n = 10
num_samples = 10000

# Generate a random sample.
a = np.random.binomial(n, 0.7, size=num_samples)

# Count the occurrences in the sample.
b = np.bincount(a, minlength=n+1)

# p is the array of probabilities.
p = b / float(b.sum())

plt.bar(np.arange(len(b)) - 0.5, p, width=1, facecolor='r',alpha=0.5)
plt.xlim(-0.5, n + 0.5)
plt.xlabel("Number of heads (k)")
plt.ylabel("P(k)")

plt.show()

# %%
n = 10
num_samples = 10000

# Generate a random sample.
a = np.random.binomial(n, (0.5+0.7)/2, size=num_samples)

# Count the occurrences in the sample.
b = np.bincount(a, minlength=n+1)

# p is the array of probabilities.
p = b / float(b.sum())

plt.bar(np.arange(len(b)) - 0.5, p, width=1, facecolor='g',alpha=0.5)
plt.xlim(-0.5, n + 0.5)
plt.xlabel("Number of heads (k)")
plt.ylabel("P(k)")

plt.show()

# %%
import plotly

# %%
import sys

# %%
sys.executable
# Out:
# '/Users/dgoldma1/anaconda/bin/python'

# %%
import matplotlib.pyplot as plt
import scipy
import scipy.stats
import seaborn as sns
sns.set_context("poster")
size = 30000
x = scipy.arange(size)
y = scipy.int_(scipy.round_(scipy.stats.vonmises.rvs(5,size=size)*47))
h = plt.hist(y, bins=range(48), color='b',edgecolor='r')

dist_names = ['gamma', 'beta', 'rayleigh', 'norm', 'pareto']

for dist_name in dist_names:
    dist = getattr(scipy.stats, dist_name)
    param = dist.fit(y)
    pdf_fitted = dist.pdf(x, *param[:-2], loc=param[-2], scale=param[-1]) * size
    plt.plot(pdf_fitted, label=dist_name)
    plt.xlim(0,47)
plt.legend(loc='upper right')
plt.show()
# Out:
# /Users/dgoldma1/anaconda/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:407: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*sqrt(a + b + 1) / (a + b + 2) / sqrt(a*b)
# /Users/dgoldma1/anaconda/lib/python3.6/site-packages/scipy/optimize/minpack.py:161: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# /Users/dgoldma1/anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:2289: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu

# %%
# Author: Jake VanderPlas
# License: BSD
#   The figure produced by this code is published in the textbook
#   "Statistics, Data Mining, and Machine Learning in Astronomy" (2013)
#   For more information, see http://astroML.github.com
#   To report a bug or issue, use the following forum:
#    https://groups.google.com/forum/#!forum/astroml-general
import numpy as np
from scipy.stats import t as student_t
from matplotlib import pyplot as plt

#----------------------------------------------------------------------
# This function adjusts matplotlib settings for a uniform feel in the textbook.
# Note that with usetex=True, fonts are rendered with LaTeX.  This may
# result in an error if LaTeX is not installed on your system.  In that case,
# you can set usetex to False.
from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=8, usetex=True)

#------------------------------------------------------------
# Define the distribution parameters to be plotted
mu = 0
k_values = [1E10, 2, 1, 0.5]
linestyles = ['-', '--', ':', '-.']
x = np.linspace(-10, 10, 1000)

#------------------------------------------------------------
# plot the distributions
fig, ax = plt.subplots(figsize=(8, 6))

for k, ls in zip(k_values, linestyles):
    dist = student_t(k, 0)

    if k >= 1E10:
        label = r'$\mathrm{t}(k=\infty)$'
    else:
        label = r'$\mathrm{t}(k=%.1f)$' % k

    plt.plot(x, dist.pdf(x), ls=ls, c='black', label=label)

plt.xlim(-5, 5)
plt.ylim(0.0, 0.45)

plt.xlabel('$x$')
plt.ylabel(r'$p(x|k)$')
plt.title("Student's $t$ Distribution")

plt.legend()
plt.show()

# %%
# Author: Jake VanderPlas
# License: BSD
#   The figure produced by this code is published in the textbook
#   "Statistics, Data Mining, and Machine Learning in Astronomy" (2013)
#   For more information, see http://astroML.github.com
#   To report a bug or issue, use the following forum:
#    https://groups.google.com/forum/#!forum/astroml-general
import numpy as np
from scipy.stats import beta
from matplotlib import pyplot as plt

#----------------------------------------------------------------------
# This function adjusts matplotlib settings for a uniform feel in the textbook.
# Note that with usetex=True, fonts are rendered with LaTeX.  This may
# result in an error if LaTeX is not installed on your system.  In that case,
# you can set usetex to False.
from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=8, usetex=True)

#------------------------------------------------------------
# Define the distribution parameters to be plotted

alpha_values = [50]
beta_values = [50]
size = alpha_values[0] + beta_values[0]

linestyles = ['-', '--', ':', '-.']
x = np.linspace(0, 1, 100002)[1:-1] 

#------------------------------------------------------------
# plot the distributions
fig, ax = plt.subplots(figsize=(5, 3.75))

for a, b, ls in zip(alpha_values, beta_values, linestyles):
    dist = beta(a, b)

    plt.plot(x-0.5, np.sqrt(size)*(dist.pdf(x)-0.5), ls=ls, c='black',
             label=r'$\alpha=%.1f,\ \beta=%.1f$' % (a, b))


plt.xlim(-1, 1)
plt.ylim(0, 100)

plt.xlabel('$x$')
plt.ylabel(r'$p(x|\alpha,\beta)$')
plt.title('Beta Distribution')

plt.legend(loc=0)
plt.show()

# %%
size
# Out:
# 2000

# %%
import pymc

# Website A had 1055 clicks and 28 sign-ups
values_A = np.hstack(([0]*(1055-28),[1]*28))

# Website B had 1057 clicks and 45 sign-ups
values_B = np.hstack(([0]*(1057-45),[1]*45))

# %%
# Create a uniform prior for the probabilities p_a and p_b
p_A = pymc.Uniform('p_A', 0, 1)
p_B = pymc.Uniform('p_B', 0, 1)

# Creates a posterior distribution of B - A
@pymc.deterministic
def delta(p_A = p_A, p_B = p_B):
    return p_B - p_A

# %%
@pymc.deterministic
def delta3(p_A = p_A, p_B = p_B):
    return p_B

# %%
# Create the Bernoulli variables for the observation
obs_A = pymc.Bernoulli('obs_A', p_A, value = values_A , observed = True)
obs_B = pymc.Bernoulli('obs_B', p_B, value = values_B , observed = True)

# Create the model and run the sampling
model = pymc.Model([p_A, p_B, delta, values_A, values_B])
mcmc = pymc.MCMC(model)

# Sample 1,000,000 million points and throw out the first 500,000
mcmc.sample(1000000, 500000)
# Out:
#  [-----------------100%-----------------] 1000000 of 1000000 complete in 108.6 sec

# %%
delta_distribution = mcmc.trace('delta')[:]
deltas = pd.Series(delta_distribution)

deltas.plot(kind="kde")
plt.axvline(0.00, color = 'black')

plt.savefig("/Users/dgoldma1/Documents/doriang102.github.io/img/bayesab.png")

# %%
print ("Probability that website A gets MORE sign-ups than site B: %0.3f" % (delta_distribution < 0).mean())
print ("Probability that website A gets LESS sign-ups than site B: %0.3f" % (delta_distribution > 0).mean())
# Out:
# Probability that website A gets MORE sign-ups than site B: 0.002
# Probability that website A gets LESS sign-ups than site B: 0.998

# %%
import numpy as np
import seaborn as sns
sns.set(style="whitegrid")

# Make an example dataset with y ~ x
rs = np.random.RandomState(7)
x = rs.normal(2, 1, 1000)
y = 2 + 1.5 * x + rs.normal(0, 2, 1000)

# Plot the residuals after fitting a linear model
sns.residplot(x, y, lowess=True, color="g")

# %%
plt.hist(y-x,linewidth=2,edgecolor='orange',bins=20)
# Out:
# (array([   1.,    3.,    6.,   16.,   22.,   71.,   77.,  115.,  146.,
#          146.,  136.,  108.,   71.,   41.,   24.,    9.,    5.,    1.,
#            1.,    1.]),
#  array([ -4.2325913 ,  -3.46506155,  -2.69753179,  -1.93000204,
#          -1.16247228,  -0.39494253,   0.37258723,   1.14011699,
#           1.90764674,   2.6751765 ,   3.44270625,   4.21023601,
#           4.97776576,   5.74529552,   6.51282527,   7.28035503,
#           8.04788478,   8.81541454,   9.5829443 ,  10.35047405,  11.11800381]),
#  <a list of 20 Patch objects>)

# %%
delta_distribution = mcmc.trace('delta')[:]

sns.kdeplot(delta_distribution, shade = True)
plt.axvline(0.00, color = 'black')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-293-c4d392c427ad> in <module>()
#       1 delta_distribution = mcmc.trace('delta')[:]
#       2
# ----> 3 sns.kdeplot(delta_distribution, shade = True)
#       4 plt.axvline(0.00, color = 'black')
#
# /Users/dgoldma1/anaconda/lib/python3.6/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, ax, **kwargs)
#     602         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     603                                  gridsize, cut, clip, legend, ax,
# --> 604                                  cumulative=cumulative, **kwargs)
#     605
#     606     return ax
#
# ...

# %%
model2 = pymc.Model([p_A, p_B, delta3, values_A, values_B])
mcmc2 = pymc.MCMC(model2)
# Sample 1,000,000 million points and throw out the first 500,000
mcmc2.sample(1000000, 500000)
# Out:
#  [-----------------100%-----------------] 1000000 of 1000000 complete in 80.2 sec

# %%
delta_distribution2 = mcmc2.trace('delta3')[:]
deltas2 = pd.Series(delta_distribution2)

# %%
len(deltas2)
# Out:
# 500000

# %%
import seaborn as sns

#sns.kdeplot(deltas, shade = True)
deltas.plot(kind="kde")

deltas2.plot(kind="kde",color='r')
#plt.axvline(0.00, color = 'black')

# %%
import numpy as np; np.random.seed(10)
import seaborn as sns; sns.set(color_codes=True)

n_R=1000
n_B=1200
p_R=0.1
p_B=0.2
samples=10000
x_R = np.random.binomial(n_R, p_R, samples)/n_R
x_B = np.random.binomial(n_B, p_R, samples)/n_R


plt.figure(figsize=(10,8))
x_R=pd.Series(x_R)
x_R.plot(kind='kde',label='Blue Button')

x_B=pd.Series(x_B)
x_B.plot(kind='kde',label='Red Button',color='r')

plt.legend()

# %%
import numpy as np; np.random.seed(10)
import seaborn as sns; sns.set(color_codes=True)

# Set number of observations.
n_R=1000
n_B=1200

# Set conversion rates of observations.
p_R=0.1
p_B=0.12

# Set number of samples to take
samples=10000

# Sample from red and blue butotn given observed conversion rates. 
x_R = np.random.binomial(n_R, p_R, samples)/n_R
x_B = np.random.binomial(n_B, p_B, samples)/n_B

# Create pandas series
x_R=pd.Series(x_R)
x_B=pd.Series(x_B)

# Plot the results. 
x_B.plot(kind='kde',label='Blue Button',color='b')
x_R.plot(kind='kde',label='Red Button',color='r')
sns.distplot(x_R,kde=False,norm_hist=True)
sns.distplot(x_B,kde=False,color='r',norm_hist=True)


x_position = 0.11
plt.axvline(x_position)
plt.legend()

# %%
np.where(x_B-x_R>0)
# Out:
# (array([   0,    1,    2, ..., 9997, 9998, 9999]),)

# %%
# Plot the difference and shade in the probability that blue is better than red. 
x_diff = x_B - x_R
x_diff.plot(kind='kde',label='Difference',color='g')
sns.distplot(x_diff[x_diff>0],kde=False,norm_hist=True)

x_position = 0.0
plt.axvline(x_position)

# %%
import numpy as np; np.random.seed(10)
import seaborn as sns; sns.set(color_codes=True)

# Set number of observations.
n_R=1000
n_B=1200

# Set conversion rates of observations.
p_R=0.1
p_B=0.12

# Set number of samples to take
samples=10000

# Sample from red and blue butotn given observed conversion rates. 
x_R = np.random.normal(p_R, np.sqrt(p_R*(1-p_R)), samples)
x_B = np.random.normal(p_B, np.sqrt(p_B*(1-p_B)), samples)

# Create pandas series
x_R=pd.Series(x_R)
x_B=pd.Series(x_B)

# Plot the results. 
x_B.plot(kind='kde',label='Blue Button',color='b')
x_R.plot(kind='kde',label='Red Button',color='r')
sns.distplot(x_R,kde=False,norm_hist=True)
sns.distplot(x_B,kde=False,color='r',norm_hist=True)

# %%
# Set number of observations.
n_R=1000
n_B=1200
for f in range(1,50,10):
    n_R = n_R*f
    n_B = n_B*f
    # Set conversion rates of observations.
    p_R=0.1
    p_B=0.12

    # Set number of samples to take
    samples=10000

    # Sample from red and blue butotn given observed conversion rates. 
    x_R = np.random.normal(p_R, np.sqrt(p_R*(1-p_R)/n_R), samples)
    x_B = np.random.normal(p_B, np.sqrt(p_B*(1-p_B)/n_B), samples)

    # Create pandas series
    x_R=pd.Series(x_R)
    x_B=pd.Series(x_B)

    # Plot the results. 
    x_B.plot(kind='kde',label='Blue Button',color='b')
    x_R.plot(kind='kde',label='Red Button',color='r')
    sns.distplot(x_R,kde=False,norm_hist=True)
    sns.distplot(x_B,kde=False,color='r',norm_hist=True)

    
    # Plot the difference and shade in the probability that blue is better than red. 
    x_diff = x_B - x_R
    x_diff.plot(kind='kde',label='Difference',color='g')
    sns.distplot(x_diff[x_diff>0],kde=False,norm_hist=True)

    x_position = 0.0
    plt.axvline(x_position)
    plt.legend()
    plt.show()

# %%
# Set number of observations.
n_R=1000
n_B=1200
fnames = 'bayes'
for f in range(1,5):
    n_R = n_R*f
    n_B = n_B*f
    # Set conversion rates of observations.
    p_R=0.1
    p_B=0.12

    # Set number of samples to take
    samples=10000

    # Sample from red and blue butotn given observed conversion rates. 
    x_R = np.random.binomial(n_R, p_R, samples)/n_R
    x_B = np.random.binomial(n_B, p_B, samples)/n_B

    # Create pandas series
    x_R=pd.Series(x_R)
    x_B=pd.Series(x_B)

    # Plot the results. 
    x_B.plot(kind='kde',label='Blue Button',color='b')
    x_R.plot(kind='kde',label='Red Button',color='r')
    sns.distplot(x_R,kde=False,norm_hist=True)
    sns.distplot(x_B,kde=False,color='r',norm_hist=True)

    
    # Plot the difference and shade in the probability that blue is better than red. 
    x_diff = x_B - x_R
    x_diff.plot(kind='kde',label='Difference',color='g')
    sns.distplot(x_diff[x_diff>0],kde=False,norm_hist=True)

    x_position = 0.0
    plt.axvline(x_position)
    plt.legend()
    plt.savefig('/Users/dgoldma1/Documents/doriang102.github.io/img/bayes' + str(f) + '.png')
    plt.show()

# %%
# Plot the difference and shade in the probability that blue is better than red. 
x_diff = x_B - x_R
x_diff.plot(kind='kde',label='Difference',color='g')
sns.distplot(x_diff[x_diff>0],kde=False,norm_hist=True)

x_position = 0.0
plt.axvline(x_position)
plt.show()

# %%
x_null[x_null>0].sum()
# Out:
# 0.4350110894450003

# %%
np.sum(x_null[x_null>0].values)
# Out:
# 0.43427971960017481

# %%
x_vals[x_vals>0].sum()
# Out:
# 45.18690635320669

# %%
n_R
# Out:
# 29360100

# %%
np.random.binomial(n_R, p_R, samples)
# Out:
# array([2936368, 2934393, 2936720, ..., 2937130, 2936112, 2935412])

# %%
# Set number of observations.
n_R=100
n_B=120

for f in range(1,5):
    n_R = n_R*f
    n_B = n_B*f
    # Set conversion rates of observations.
    p_R=0.1
    p_B=0.12

    # Set number of samples to take
    samples=10000

    x_null=np.random.normal(0, np.sqrt(p_R*(1-p_R)/n_R) + np.sqrt(p_B*(1-p_B)/n_B), samples)
 
    # Create pandas series
    x_null=pd.Series(x_null)
    plt.xlim([-0.5,0.5])
    
    # Plot the distribution
    x_null.plot(kind='kde',label='N=' + str(n_R),color='g')
    x_null_p = x_null[x_null>0.02]
    sns.distplot(x_null_p,kde=False,norm_hist=True)

    # Plot the observed difference of p_B-p_R.
    x_position = 0.02
    plt.axvline(x_position)

    plt.legend()
    plt.show()

# %%
import numpy as np

# %%
import seaborn as sns
delta_distribution = mcmc.trace('delta')[:]
deltas = pd.Series(delta_distribution)
#sns.kdeplot(deltas, shade = True)
deltas.plot(kind="kde")
plt.axvline(0.00, color = 'black')

# %%
print ("Probability that website A gets MORE sign-ups than site B: %0.3f" % (delta_distribution < 0).mean())
print ("Probability that website A gets LESS sign-ups than site B: %0.3f" % (delta_distribution > 0).mean())
# Out:
# Probability that website A gets MORE sign-ups than site B: 0.022
# Probability that website A gets LESS sign-ups than site B: 0.978

# %%
# Author: Jake VanderPlas
# License: BSD
#   The figure produced by this code is published in the textbook
#   "Statistics, Data Mining, and Machine Learning in Astronomy" (2013)
#   For more information, see http://astroML.github.com
#   To report a bug or issue, use the following forum:
#    https://groups.google.com/forum/#!forum/astroml-general
import numpy as np
from scipy.stats import binom
from matplotlib import pyplot as plt

#----------------------------------------------------------------------
# This function adjusts matplotlib settings for a uniform feel in the textbook.
# Note that with usetex=True, fonts are rendered with LaTeX.  This may
# result in an error if LaTeX is not installed on your system.  In that case,
# you can set usetex to False.
from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=8, usetex=True)

#------------------------------------------------------------
# Define the distribution parameters to be plotted
n_values = [20, 50, 100,500]
b_values = [0.2, 0.2, 0.2]
linestyles = ['-', '--', ':']
x = np.arange(-1, 200)

#------------------------------------------------------------
# plot the distributions
fig, ax = plt.subplots(figsize=(8, 6))

for (n, b, ls) in zip(n_values, b_values, linestyles):
    # create a binomial distribution
    dist = binom(n, b)

    plt.plot(x/n, dist.pmf(x/n), ls=ls, c='black',
             label=r'$b=%.1f,\ n=%i$' % (b, n), linestyle='steps-mid')

plt.xlim(0,1)
#plt.ylim(0, 1)

plt.xlabel('$x$')
plt.ylabel(r'$p(x|b, n)$')
plt.title('Binomial Distribution')

plt.legend()
plt.show()
# Out:
# /Users/dgoldma1/anaconda/lib/python3.6/site-packages/matplotlib/cbook.py:2649: UserWarning: Saw kwargs ['ls', 'linestyle'] which are all aliases for 'linestyle'.  Kept value from 'linestyle'
#   seen=seen, canon=canonical, used=seen[-1]))
